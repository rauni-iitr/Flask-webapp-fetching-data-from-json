# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import spacy
import re

# %% [markdown]
# Loading Spacy Toolkit and reading data through pandas

# %%
nlp=spacy.load('en_core_web_sm')

# %%
df=pd.read_csv('IMDB Dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     50000 non-null  object
#  1   sentiment  50000 non-null  object
# dtypes: object(2)
# memory usage: 781.4+ KB

# %%
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %% [markdown]
# ### Function to clean the text; hyperlink removal, square brackets removal, special characters removal

# %%
def strip_url(text):
    return re.sub(r"http\S+", '', text)
def strip_brackets(text):
    return re.sub('\[[^]]*\]', '', text)
def strip_spl_char(text, remove_digits=True):
    pattern=r'[^a-zA-z0-9\s]'
    text=re.sub(pattern,'',text)
    return text
def clean(text):
    text=strip_url(text)
    text=strip_brackets(text)
    text=strip_spl_char(text)
    return text

# %%
df['review']=df['review'].apply(clean)

# %%
df['review'].head()
# Out:
# 0    One of the other reviewers has mentioned that ...
# 1    A wonderful little production br br The filmin...
# 2    I thought this was a wonderful way to spend ti...
# 3    Basically theres a family where a little boy J...
# 4    Petter Matteis Love in the Time of Money is a ...
# Name: review, dtype: object

# %%
df=df.loc[:4999]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     5000 non-null   object
#  1   sentiment  5000 non-null   object
# dtypes: object(2)
# memory usage: 78.2+ KB

# %% [markdown]
# Working on 5000 datapoints; Using SpaCy NER, finding labels in reviews which comes under "GPE" and "PERSON" and extracting them to list of tuples.
#
# "GPE"- entity label consists of Country,States and Cities.
# Problem statement asks for only cities.
#
# Also, In the "PERSON" entity its mostly not usernames but names of person(usually actors and characters) mentioned in reviews as its highly unlikely for user to mention their own names.

# %%
list_ner=[]
def add(text):
    doc=nlp(text)
    for ent in doc.ents:
        if (ent.label_=='GPE'):
            tup=(ent.text,'City')
            list_ner.append(tup)
        elif (ent.label_=='PERSON'):
            tup=(ent.text,'Person')
            list_ner.append(tup)

# %%
df['review'].apply(add)
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 4995    None
# 4996    None
# 4997    None
# 4998    None
# 4999    None
# Name: review, Length: 5000, dtype: object

# %%
list_ner
# Out:
# [('Oz', 'Person'),
#  ('Emerald City', 'City'),
#  ('Oz', 'Person'),
#  ('Oz', 'Person'),
#  ('Michael Sheen', 'Person'),
#  ('Williams', 'Person'),
#  ('Orton', 'Person'),
#  ('Halliwell', 'Person'),
#  ('Woody Allen', 'Person'),
#  ('Scarlet Johanson', 'Person'),
#  ('Devil Wears Prada', 'Person'),
#  ('Jake', 'Person'),
#  ('Jake', 'Person'),
#  ('Rambo', 'Person'),
#  ('Jake', 'Person'),
#  ('Jake', 'City'),
#  ('Petter Matteis Love', 'Person'),
#  ('Mr Mattei', 'Person'),
#  ('Arthur', 'Person'),
#  ('New York', 'City'),
#  ('Mr Matteis', 'Person'),
#  ('Steve Buscemi Rosario Dawson Carol Kane', 'Person'),
#  ('Michael Imperioli', 'Person'),
#  ('Adrian Grenier', 'Person'),
#  ('Mr Mattei', 'Person'),
#  ('Paul Lukas', 'Person'),
#  ('Bette Davis', 'Person'),
#  ('weekYou', 'Person'),
#  ('Harvey Keitel', 'City'),
#  ('Phil the Alien', 'Person'),
#  ('Psycho', 'Person'),
#  ('Janet Leigh', 'Person'),
#  ('Ralf Moellerbr', 'Person'),
#  ('Jack Carver', 'Person'),
#  ('Til Schweiger', 'Person'),
#  ('Carver', 'City'),
#  ('Tils', 'City'),
#  ('Udo Kier', 'Person'),
#  ('mehehe', 'City'),
#  ('Shakespeare', 'Person'),
#  ('Shakespeare', 'Person'),
#  ('Shakespeare', 'Person'),
#  ('Rev Bowdler', 'Person'),
#  ('george clooney', 'Person'),
#  ('Greetings Bart', 'Person'),
#  ('Rosanna Arquette', 'Person'),
#  ('Liam Neeson', 'Person'),
#  ('Owen Wilson', 'Person'),
#  ('Luke', 'Person'),
#  ('Shirley Jackson', 'Person'),
#  ('Matrix br br Examplesbr', 'Person'),
#  ('Yoda Obee', 'Person'),
#  ('hellobr br', 'Person'),
#  ('Newbury', 'City'),
#  ('Grizzly Adams', 'Person'),
#  ('Dan Haggery', 'Person'),
#  ('knowThe', 'Person'),
#  ('Cliffhanger Die Hard', 'Person'),
#  ('Sly Stop', 'Person'),
#  ('Cliffhanger', 'Person'),
#  ('John Lithgows', 'Person'),
#  ('Rex Linn', 'Person'),
#  ('Michael Rooker', 'Person'),
#  ('Ralph Waites Frank', 'Person'),
#  ('Londons Burning', 'Person'),
#  ('Craig Fairbrass', 'Person'),
#  ('Rajnikanth', 'Person'),
#  ('Speed Racer', 'Person'),
#  ('Preschool', 'City'),
#  ('Godzilla', 'Person'),
#  ('Godzilla', 'Person'),
#  ('JoelMike', 'Person'),
#  ('Karen Carpenters', 'Person'),
#  ('Cynthia Gibb', 'Person'),
#  ('Karen', 'Person'),
#  ('Karen Carpenter', 'Person'),
#  ('Louise Fletcher', 'Person'),
#  ('Agnes Carpenter', 'Person'),
#  ('USA', 'City'),
#  ('Tarsem Singh', 'Person'),
#  ('Tarsem', 'City'),
#  ('Jennifer Lopez', 'Person'),
#  ('The Cell', 'Person'),
#  ('Oscars', 'City'),
#  ('Hollywood', 'City'),
#  ('Latino', 'Person'),
#  ('Horrible', 'Person'),
#  ('Hollywood', 'City'),
#  ('Jude Law Nicole Kidman', 'Person'),
#  ('Rene Zellweger', 'Person'),
#  ('Edward Zwick', 'Person'),
#  ('Jude Law', 'Person'),
#  ('Ada Monroe', 'Person'),
#  ('Nicole Kidman', 'Person'),
#  ('Inman', 'Person'),
#  ('Ruby Thewes', 'Person'),
#  ('Rene Zellweger', 'Person'),
#  ('Inman', 'Person'),
#  ('Brendan Gleeson', 'Person'),
#  ('Ray Winstone', 'Person'),
#  ('Natalie Portman', 'Person'),
#  ('Virginia', 'City'),
#  ('North Carolina', 'City'),
#  ('Anthony Minghella', 'Person'),
#  ('Edward Dmytryks Crossfire', 'Person'),
#  ('Bivouacked', 'City'),
#  ('Washington DC', 'City'),
#  ('Robert Ryan', 'Person'),
#  ('Sam Levene', 'Person'),
#  ('Robert Young', 'Person'),
#  ('Robert Mitchum', 'Person'),
#  ('George Cooper', 'Person'),
#  ('Ryan', 'Person'),
#  ('Steve Brodie', 'Person'),
#  ('John Paxton Dmytryk', 'Person'),
#  ('Bobs Ryan', 'Person'),
#  ('Angry White Male', 'Person'),
#  ('Mitchum', 'Person'),
#  ('Young', 'Person'),
#  ('Gloria Grahame', 'Person'),
#  ('Paul Kelly', 'Person'),
#  ('Ryan', 'Person'),
#  ('Crossfire', 'Person'),
#  ('Richard Brooks', 'Person'),
#  ('Brick Foxhole', 'Person'),
#  ('Hollywood', 'City'),
#  ('homophobia', 'City'),
#  ('Ardh Satya', 'Person'),
#  ('Govind Nihalani', 'Person'),
#  ('Ardh Satya', 'Person'),
#  ('India', 'City'),
#  ('Anand Velankar', 'Person'),
#  ('Cop', 'Person'),
#  ('Constable Anand', 'City'),
#  ('Anands', 'Person'),
#  ('Anands', 'City'),
#  ('Spirit', 'Person'),
#  ('Anand', 'Person'),
#  ('Underworld', 'City'),
#  ('Rama Shettys', 'Person'),
#  ('Mumbai', 'City'),
#  ('Anand Velankar', 'Person'),
#  ('Titta Di', 'Person'),
#  ('Girolamo', 'City'),
#  ('Switzerland', 'City'),
#  ('Di Girolamos', 'Person'),
#  ('Titta', 'City'),
#  ('Girolamos', 'City'),
#  ('Titta', 'City'),
#  ('Titta', 'City'),
#  ('Girolamo', 'City'),
#  ('Never', 'Person'),
#  ('Hollywood', 'City'),
#  ('Italy', 'City'),
#  ('Anna', 'Person'),
#  ('Tittas', 'City'),
#  ('Titta', 'City'),
#  ('Titta', 'City'),
#  ('Italy', 'City'),
#  ('London', 'City'),
#  ('London', 'City'),
#  ('Blockbuster', 'Person'),
#  ('Ranmaesque', 'Person'),
#  ('Ray Stevens', 'Person'),
#  ('Jesus Wear', 'Person'),
#  ('PG13', 'Person'),
#  ('Blockbuster', 'Person'),
#  ('Zack', 'Person'),
#  ('Reba', 'City'),
#  ('The Virgin Suicides', 'City'),
#  ('hopebr br', 'Person'),
#  ('UK', 'City'),
#  ('David Morses', 'Person'),
#  ('David Morse', 'Person'),
#  ('David Koepp', 'Person'),
#  ('US', 'City'),
#  ('Iraq', 'City'),
#  ('Nicholas Cage', 'Person'),
#  ('misogyny', 'Person'),
#  ('James Wood', 'Person'),
#  ('Cuba', 'City'),
#  ('China', 'City'),
#  ('Hong Kong', 'City'),
#  ('Jennifer Jones', 'Person'),
#  ('Oscar', 'Person'),
#  ('China', 'City'),
#  ('William Holden', 'Person'),
#  ('Hong Kong', 'City'),
#  ('Hollywood', 'City'),
#  ('Gary Busey', 'Person'),
#  ('Gary', 'Person'),
#  ('Dutcher', 'Person'),
#  ('Mormon', 'Person'),
#  ('Dutcher', 'Person'),
#  ('laughablebr br Dutchers', 'Person'),
#  ('Mormon', 'City'),
#  ('Dutcher', 'Person'),
#  ('Mormon', 'Person'),
#  ('Dutcher', 'Person'),
#  ('Mormon', 'City'),
#  ('California', 'City'),
#  ('Dutcher', 'Person'),
#  ('Michael Douglas', 'Person'),
#  ('Kasey', 'Person'),
#  ('Goldie Hawn', 'Person'),
#  ('a Goldie Hawn', 'Person'),
#  ('Drama', 'Person'),
#  ('John Voight', 'Person'),
#  ('Mary Steenburgen', 'Person'),
#  ('Hercules Abraham', 'Person'),
#  ('Moses', 'Person'),
#  ('Noah Lot Abrahams', 'City'),
#  ('Lot', 'Person'),
#  ('Noah', 'Person'),
#  ('Lot', 'Person'),
#  ('Herman Mankiewicz', 'Person'),
#  ('Orson Welles', 'Person'),
#  ('Kael', 'Person'),
#  ('Charles Foster Kane', 'Person'),
#  ('Ralston', 'Person'),
#  ('Bernstein Jed', 'Person'),
#  ('Susan Alexander Kane', 'Person'),
#  ('Raymond', 'Person'),
#  ('Kane', 'Person'),
#  ('KANE', 'Person'),
#  ('Tom Garner Spencer', 'Person'),
#  ('Henry Ralph Morgan', 'Person'),
#  ('Sarah Padden', 'Person'),
#  ('Kane', 'Person'),
#  ('Garner Henry', 'Person'),
#  ('Tom', 'Person'),
#  ('Henry', 'Person'),
#  ('Toms', 'Person'),
#  ('Tom', 'Person'),
#  ('Orson Welles', 'Person'),
#  ('Colleen Moore', 'Person'),
#  ('Sally', 'Person'),
#  ('Tom', 'Person'),
#  ('America', 'City'),
#  ('Tom', 'Person'),
#  ('Sally', 'Person'),
#  ('Eve Helen Vinson', 'Person'),
#  ('Sally', 'Person'),
#  ('Tom', 'Person'),
#  ('Henry Eve', 'Person'),
#  ('Tom', 'Person'),
#  ('Toms', 'Person'),
#  ('Tom Jr Philip', 'Person'),
#  ('Tom', 'Person'),
#  ('Tom', 'Person'),
#  ('Sturgis', 'Person'),
#  ('Fulcis', 'City'),
#  ('Hollywood', 'City'),
#  ('Gordon Liu', 'Person'),
#  ('Liu', 'Person'),
#  ('Shaolin', 'Person'),
#  ('Shaolin Temple', 'Person'),
#  ('Mr Miyagis', 'Person'),
#  ('Karate Kid', 'City'),
#  ('Yuen Wo Ping', 'Person'),
#  ('Hollywood', 'City'),
#  ('Jimmy Davis', 'Person'),
#  ('Jimmy Davis', 'Person'),
#  ('Jimmy', 'Person'),
#  ('Fred P Willis Spencer', 'Person'),
#  ('France', 'City'),
#  ('Jimmy', 'Person'),
#  ('Jimmy', 'Person'),
#  ('Rose Duffy Gladys George Rose', 'Person'),
#  ('Fred', 'Person'),
#  ('Fred', 'Person'),
#  ('Rose', 'Person'),
#  ('Jimmy', 'Person'),
#  ('Fred', 'Person'),
#  ('Jimmy', 'City'),
#  ('Rose', 'Person'),
#  ('Rose', 'Person'),
#  ('Fred', 'Person'),
#  ('Fred', 'Person'),
#  ('Jimmy', 'Person'),
#  ('New York City', 'City'),
#  ('Jimmy', 'Person'),
#  ('New York Citys', 'City'),
#  ('Fred later', 'Person'),
#  ('Rose', 'Person'),
#  ('Jimmy', 'Person'),
#  ('Jimmy', 'Person'),
#  ('Jimmy', 'Person'),
#  ('Rose', 'Person'),
#  ('Fred', 'Person'),
#  ('Jimmy', 'Person'),
#  ('Jimmy', 'Person'),
#  ('Rose', 'Person'),
#  ('Fred', 'Person'),
#  ('Jimmy', 'Person'),
#  ('Jimmy', 'Person'),
#  ('Bela Lugosi', 'Person'),
#  ('Bela', 'Person'),
#  ('Belas', 'City'),
#  ('Bela', 'Person'),
#  ('Bela Lugosi', 'Person'),
#  ('W Bush', 'Person'),
#  ('Robespierre', 'Person'),
#  ('Selfdefense', 'Person'),
#  ('Gordon Eriksen', 'Person'),
#  ('gore', 'Person'),
#  ('The Hills Have', 'City'),
#  ('Hattie McDaniel', 'Person'),
#  ('Hitchcocks', 'Person'),
#  ('Rebecca', 'Person'),
#  ('Daphne DuMariers', 'Person'),
#  ('US', 'City'),
#  ('Jack Skirball', 'Person'),
#  ('Dorothy Parker', 'Person'),
#  ('Hollywood', 'City'),
#  ('Barry Kane Robert Cummings', 'Person'),
#  ('Frank Frye Norman Lloydd', 'Person'),
#  ('Soda City Utah', 'City'),
#  ('New York City', 'City'),
#  ('Patricia Martin Priscilla Lane', 'Person'),
#  ('Hitchcock Patricia', 'Person'),
#  ('Barry falls', 'Person'),
#  ('Hollywood', 'City'),
#  ('Saboteur', 'Person'),
#  ('Hitchcocks', 'Person'),
#  ('Albert Finney', 'Person'),
#  ('Tom Courtenay', 'Person'),
#  ('The Dresser', 'Person'),
#  ('Finney', 'Person'),
#  ('Norman Courtenay', 'Person'),
#  ('King Lear', 'Person'),
#  ('London', 'City'),
#  ('Norman', 'Person'),
#  ('Norman', 'Person'),
#  ('Finney', 'Person'),
#  ('Courtenay', 'Person'),
#  ('Employer', 'Person'),
#  ('Norman', 'Person'),
#  ('Finney Courtenay', 'Person'),
#  ('Ronald Harwood', 'Person'),
#  ('Eileen Atkins', 'Person'),
#  ('Madge', 'Person'),
#  ('Finney', 'Person'),
#  ('Peter Yates', 'Person'),
#  ('Steve Martin', 'Person'),
#  ('Kate', 'Person'),
#  ('Fingersmith', 'Person'),
#  ('lets beginbr', 'Person'),
#  ('JJL', 'Person'),
#  ('Stella Bette Midler', 'Person'),
#  ('Stephen Collins', 'Person'),
#  ('Jenny Trini Alvarado', 'Person'),
#  ('Stella Dallas', 'Person'),
#  ('Midler', 'Person'),
#  ('Midler', 'Person'),
#  ('Alvarado', 'Person'),
#  ('Stephen Collins', 'Person'),
#  ('Marsha Mason', 'Person'),
#  ('Flimsy', 'Person'),
#  ('Reallywho', 'Person'),
#  ('Stanwyck', 'Person'),
#  ('Fulcis', 'City'),
#  ('gore', 'Person'),
#  ('Fulcis', 'Person'),
#  ('Fulcis', 'City'),
#  ('Busty', 'City'),
#  ('Jim Wynorski', 'Person'),
#  ('Salman Kahn', 'Person'),
#  ('Salman', 'Person'),
#  ('Salman', 'Person'),
#  ('Marques Houston', 'Person'),
#  ('Okayso Reid', 'Person'),
#  ('Martin', 'Person'),
#  ('m sorryKym Whitley', 'Person'),
#  ('Robin Harris Ketty', 'Person'),
#  ('Meagen Good', 'Person'),
#  ('Mari Morrow', 'Person'),
#  ('Hudlin', 'Person'),
#  ('Max Q', 'Person'),
#  ('Bill Campbell', 'Person'),
#  ('Bill Campbell', 'Person'),
#  ('Robert Stack', 'Person'),
#  ('Ted Knight', 'Person'),
#  ('Jackie Mason', 'Person'),
#  ('Rodney Dangerfield Ty Webb', 'Person'),
#  ('Henry Wilcoxon', 'Person'),
#  ('Peter Blunt', 'Person'),
#  ('Randy Quaid', 'Person'),
#  ('Dan Acroyd', 'Person'),
#  ('Bill Murray', 'Person'),
#  ('necrophilia', 'City'),
#  ('gore', 'Person'),
#  ('gore', 'Person'),
#  ('GENESIS', 'Person'),
#  ('Cerda', 'Person'),
#  ('Mukhsin', 'Person'),
#  ('Yasmin', 'Person'),
#  ('Gubra', 'Person'),
#  ('Gubra', 'City'),
#  ('Rumah', 'Person'),
#  ('Mukhsins', 'Person'),
#  ('Harry Vardon', 'Person'),
#  ('Francis', 'Person'),
#  ('Francis', 'City'),
#  ('Ed Wood', 'Person'),
#  ('Ed', 'Person'),
#  ('Russ Meyer', 'Person'),
#  ('Ren Hoek', 'Person'),
#  ('Tobe Hoopers', 'Person'),
#  ('Blood Surf', 'Person'),
#  ('Jaws Temple', 'Person'),
#  ('James Bond', 'Person'),
#  ('Sh Kasugi', 'Person'),
#  ('Christopher Lee', 'Person'),
#  ('JohnRhys', 'Person'),
#  ('Errol Flynn', 'Person'),
#  ('Hollywood', 'City'),
#  ('James Coburn', 'Person'),
#  ('Charlton Heston', 'Person'),
#  ('Barbara Hershey Coburn', 'Person'),
#  ('Heston', 'Person'),
#  ('James Coburn', 'Person'),
#  ('Coburn', 'Person'),
#  ('Heston', 'Person'),
#  ('Hershey', 'City'),
#  ('Heston', 'Person'),
#  ('Morgan', 'Person'),
#  ('Thalmus Rasulala John Quade', 'Person'),
#  ('Larry Wilcox', 'Person'),
#  ('Jorge Rivero Heston', 'Person'),
#  ('Chris Mitchum', 'Person'),
#  ('Andrew McLaglen', 'Person'),
#  ('Porno Holocaust', 'Person'),
#  ('Entrails', 'Person'),
#  ('Kazuo Gaira Komizu', 'Person'),
#  ('Murderer', 'Person'),
#  ('Olympic', 'City'),
#  ('Gaira', 'Person'),
#  ('Entrails', 'Person'),
#  ('Sharif', 'Person'),
#  ('God', 'Person'),
#  ('Kurtz', 'Person'),
#  ('Cuba', 'City'),
#  ('Hollywood', 'City'),
#  ('Medved', 'City'),
#  ('Doug Block', 'Person'),
#  ('Mina', 'Person'),
#  ('Mike', 'Person'),
#  ('Mike', 'Person'),
#  ('Minas', 'Person'),
#  ('Doug', 'Person'),
#  ('Doug', 'Person'),
#  ('Stephen Hawkings', 'Person'),
#  ('Stephen Hawkings', 'Person'),
#  ('Einstein', 'Person'),
#  ('Lou Gehrigs', 'Person'),
#  ('Nora Roberts', 'Person'),
#  ('Australia', 'City'),
#  ('Blood Surf', 'Person'),
#  ('Primeval', 'Person'),
#  ('Walter Sparrow', 'Person'),
#  ('Joel Schumacher', 'Person'),
#  ('Carrey', 'Person'),
#  ('Carrey', 'Person'),
#  ('Jim Carrey', 'Person'),
#  ('Virginia Madsen', 'Person'),
#  ('Logan Lerman', 'Person'),
#  ('Danny Huston', 'Person'),
#  ('Drew Fuller', 'Person'),
#  ('Steele', 'Person'),
#  ('Ophelia', 'Person'),
#  ('Gilbert', 'Person'),
#  ('Brad Johnson', 'Person'),
#  ('Matt', 'Person'),
#  ('Pip', 'Person'),
#  ('Ophelia', 'Person'),
#  ('Matt', 'Person'),
#  ('Janine Turner', 'Person'),
#  ('Steele', 'Person'),
#  ('Nicholas Walker', 'Person'),
#  ('Paul', 'Person'),
#  ('Reverand', 'Person'),
#  ('Martha Ally Sheedy', 'Person'),
#  ('Veronica Dara Tomanovich', 'Person'),
#  ('Sally Kirkland', 'Person'),
#  ('Reverand', 'Person'),
#  ('John Savage', 'Person'),
#  ('Sally Kirkland', 'Person'),
#  ('Hollywood', 'City'),
#  ('Daredevil Elektra Ghost Rider', 'Person'),
#  ('Gore Verbinsky', 'Person'),
#  ('Grudge', 'Person'),
#  ('Amber Tamblyn', 'Person'),
#  ('Aubrey Tamblyn', 'Person'),
#  ('Karen Sarah Michelle Gellar', 'Person'),
#  ('Allison Arielle Kebbel', 'Person'),
#  ('Glad', 'Person'),
#  ('Hollywood', 'City'),
#  ('Down Periscope', 'Person'),
#  ('Mobile', 'City'),
#  ('Alabama', 'City'),
#  ('Cub Scouts', 'Person'),
#  ('Hollywood', 'City'),
#  ('Kelsey Grammar Lauren Holly', 'Person'),
#  ('Rob Schneider', 'Person'),
#  ('Blade', 'City'),
#  ('Deanna Durbin Nan Grey', 'Person'),
#  ('Barbara Read', 'Person'),
#  ('Universal', 'Person'),
#  ('Deanna Durbin', 'Person'),
#  ('Ray Milland', 'Person'),
#  ('Mischa Auer', 'Person'),
#  ('Charles Winninger', 'Person'),
#  ('John King Binnie Barnes', 'Person'),
#  ('Alice Brady', 'Person'),
#  ('Switzerland', 'City'),
#  ('Winninger', 'Person'),
#  ('America', 'City'),
#  ('Brady', 'Person'),
#  ('Auer', 'Person'),
#  ('Milland', 'Person'),
#  ('Auer Milland Barnes', 'Person'),
#  ('Brady', 'Person'),
#  ('Durbin', 'Person'),
#  ('Il Bacio', 'City'),
#  ('Charles Winninger', 'Person'),
#  ('Ray Milland', 'Person'),
#  ('Deanna', 'Person'),
#  ('Italy', 'City'),
#  ('England', 'City'),
#  ('Alfred Molina', 'Person'),
#  ('Lawrence Jim', 'Person'),
#  ('Miranda Richardson', 'Person'),
#  ('Michael Kitchens', 'Person'),
#  ('Mike Newell', 'Person'),
#  ('Cedric Hardwicke', 'Person'),
#  ('LASTING', 'City'),
#  ('Daniel DayLewis', 'Person'),
#  ('Cristy Brown', 'Person'),
#  ('Cristy Brown', 'Person'),
#  ('Cristy Brown', 'Person'),
#  ('Hollywood', 'City'),
#  ('Eileen Peter', 'Person'),
#  ('Daniel DayLewis', 'Person'),
#  ('Ill kick', 'Person'),
#  ('Cristys', 'City'),
#  ('sho yo', 'Person'),
#  ('Zeus', 'Person'),
#  ('Hera', 'Person'),
#  ('Zeus', 'Person'),
#  ('Ed Woods', 'Person'),
#  ('George W Bush', 'Person'),
#  ('Stay', 'Person'),
#  ('Mario', 'Person'),
#  ('Mario', 'Person'),
#  ('Mario', 'Person'),
#  ('Mario', 'Person'),
#  ('Mario', 'Person'),
#  ('Mario', 'Person'),
#  ('Mario', 'Person'),
#  ('Bowser', 'Person'),
#  ('Bowser Jr', 'Person'),
#  ('Bowser', 'Person'),
#  ('Princess Peach', 'Person'),
#  ('Mario falls', 'Person'),
#  ('Mario', 'Person'),
#  ('Luma', 'Person'),
#  ('Mario', 'Person'),
#  ('Rosalina Rosalina', 'Person'),
#  ('Mario', 'Person'),
#  ('Bowser', 'Person'),
#  ('Mario', 'Person'),
#  ('Lumas', 'City'),
#  ('Peach', 'Person'),
#  ('Mario', 'Person'),
#  ('Stars Mario', 'Person'),
#  ('Mario', 'Person'),
#  ('Mario', 'Person'),
#  ('Spatula Madness', 'Person'),
#  ('Edward the Spatula', 'Person'),
#  ('Hollywood', 'City'),
#  ('Mr Van Bebble', 'Person'),
#  ('Chicago', 'City'),
#  ('Oliver Stone', 'Person'),
#  ('Terry Gilliam', 'Person'),
#  ('Mr Van Bebble', 'Person'),
#  ('Charlie', 'Person'),
#  ('Van Bebbles', 'Person'),
#  ('Helter Skelter', 'Person'),
#  ('Mtv', 'Person'),
#  ('Rocky Horroresque', 'Person'),
#  ('America', 'City'),
#  ('Lie', 'Person'),
#  ('Mtv', 'Person'),
#  ('Charlie', 'Person'),
#  ('Dungeons', 'Person'),
#  ('Sadie', 'Person'),
#  ('Linda', 'Person'),
#  ('madeforTV', 'Person'),
#  ('Richard Crenna', 'Person'),
#  ('Yvette Mimieux', 'Person'),
#  ('Jackson County', 'City'),
#  ('Kim Richards', 'Person'),
#  ('Ike Eisenmann', 'Person'),
#  ('Martine Beswicke', 'Person'),
#  ('RG Armstrong', 'Person'),
#  ('Victor Jory', 'Person'),
#  ('Savannah', 'City'),
#  ('Georgia', 'City'),
#  ('Hollywood', 'City'),
#  ('Dell Henderson', 'Person'),
#  ('William Haines', 'Person'),
#  ('Andre Telefair', 'Person'),
#  ('Hollywood', 'City'),
#  ('William Haines', 'Person'),
#  ('Charles Chaplin', 'Person'),
#  ('John Gilbert', 'Person'),
#  ('Kronos', 'City'),
#  ('Klingon', 'City'),
#  ('Kirk', 'Person'),
#  ('William Shatner', 'Person'),
#  ('McCoy', 'Person'),
#  ('Shatner', 'Person'),
#  ('Kirk', 'Person'),
#  ('Kane', 'Person'),
#  ('Spencer Tracy', 'Person'),
#  ('Spencer Tracy', 'Person'),
#  ('Colleen Moore', 'Person'),
#  ('Helen Vinson', 'Person'),
#  ('Dalton', 'Person'),
#  ('Rochester', 'Person'),
#  ('Jane Eyre', 'Person'),
#  ('Zelah Clark', 'Person'),
#  ('Jane Eyre', 'Person'),
#  ('Jonathan Tanner', 'Person'),
#  ('Cox', 'Person'),
#  ('Borges', 'Person'),
#  ('Lonnrot', 'Person'),
#  ('Aussie', 'Person'),
#  ('Aidan Quinn', 'Person'),
#  ('Quinn', 'City'),
#  ('Donald Sutherland', 'Person'),
#  ('Quinn Ben Kingsley', 'Person'),
#  ('paris', 'City'),
#  ('Louis XVI', 'Person'),
#  ('Danton Gerard Depardieu', 'Person'),
#  ('Wojciech Pszoniak', 'Person'),
#  ('Paris', 'City'),
#  ('Robespierre', 'Person'),
#  ('Robespierre', 'Person'),
#  ('Robespierre', 'Person'),
#  ('Andrzej Wajda', 'Person'),
#  ('France', 'City'),
#  ('Poland', 'City'),
#  ('Lech Walesa', 'Person'),
#  ('Jaruselski', 'Person'),
#  ('Danton', 'Person'),
#  ('Robespierre DantonWalesa', 'Person'),
#  ('Stanislawa Przybyszewska', 'Person'),
#  ('Paris', 'City'),
#  ('Corey Haims', 'Person'),
#  ('Nicole Eggert', 'Person'),
#  ('Pedro Almodvar', 'Person'),
#  ('Margaret Atwoods', 'Person'),
#  ('Zenias', 'Person'),
#  ('Roz Charis', 'Person'),
#  ('Toni', 'Person'),
#  ('Zenias', 'Person'),
#  ('Margaret Atwood', 'Person'),
#  ('gore', 'Person'),
#  ('gore', 'Person'),
#  ('gore', 'Person'),
#  ('Ingrid Bergman', 'Person'),
#  ('Walter Matthaus', 'Person'),
#  ('Goldie Hawn', 'Person'),
#  ('Matthau', 'Person'),
#  ('Goldie Hawn', 'Person'),
#  ('Bergman', 'Person'),
#  ('Goldie', 'Person'),
#  ('Hawn', 'Person'),
#  ('Learning', 'City'),
#  ('Winston Rekert', 'Person'),
#  ('Paul Sharpes', 'Person'),
#  ('Andrew Bednarski', 'Person'),
#  ('Matthew Sharpe', 'Person'),
#  ('John Novak', 'Person'),
#  ('Stewart Kaufman', 'Person'),
#  ('Rekert Mr', 'Person'),
#  ('Karen Black', 'Person'),
#  ('Janus', 'Person'),
#  ('Rekert', 'Person'),
#  ('Chuck', 'Person'),
#  ('RAMBO', 'Person'),
#  ('Edgar Allen', 'Person'),
#  ('Boris Karloff', 'Person'),
#  ('Dan Basinger 810', 'Person'),
#  ('Jack Frost', 'Person'),
#  ('Waaaaaaaaaaay', 'City'),
#  ('Michael Keaton', 'Person'),
#  ('revamp', 'Person'),
#  ('Halperin', 'Person'),
#  ('White Zombie', 'Person'),
#  ('Halperins', 'Person'),
#  ('Zombie', 'Person'),
#  ('Victor Halperin', 'Person'),
#  ('Ugly Betty', 'Person'),
#  ('Tim Daly', 'Person'),
#  ('Chris Lowell', 'Person'),
#  ('Hospitalor', 'Person'),
#  ('Ebert', 'Person'),
#  ('Ebert', 'Person'),
#  ('Yea', 'Person'),
#  ('Steve', 'Person'),
#  ('Jack Barclays', 'Person'),
#  ('Tony Leung', 'Person'),
#  ('Maggie Cheung', 'Person'),
#  ('Hong Kong', 'City'),
#  ('Bill Murray', 'Person'),
#  ('Bill Murray', 'Person'),
#  ('Rudy', 'Person'),
#  ('Chris Makepeace', 'Person'),
#  ('Murray', 'Person'),
#  ('Murray', 'Person'),
#  ('Corey Feldman', 'Person'),
#  ('Kool Moe Dee Carol Alt', 'Person'),
#  ('Corey Feldman', 'Person'),
#  ('washedup hasbeen', 'Person'),
#  ('neverwass', 'Person'),
#  ('Gary Coleman', 'Person'),
#  ('Carol Alt', 'Person'),
#  ('Carol', 'Person'),
#  ('Anna Nicole Smith', 'Person'),
#  ('Ms Englishs', 'Person'),
#  ('Ms Englishs', 'Person'),
#  ('Meg Ryan', 'Person'),
#  ('Annette Bening', 'Person'),
#  ('New Yorker', 'City'),
#  ('Lets', 'Person'),
#  ('Lee Radziwill', 'Person'),
#  ('Little Edie', 'Person'),
#  ('Yeoman Barrows', 'Person'),
#  ('Gene Roddenberry', 'Person'),
#  ('Irwin Allen', 'Person'),
#  ('curiosity', 'City'),
#  ('Mork', 'Person'),
#  ('Mindy', 'Person'),
#  ('Robin Williams', 'Person'),
#  ('Robin', 'Person'),
#  ('Robin', 'Person'),
#  ('Robins', 'Person'),
#  ('Chris Diamantopoulos', 'Person'),
#  ('Mr Williams', 'Person'),
#  ('Andy Kaufman', 'Person'),
#  ('Garry Marshall', 'Person'),
#  ('John Belushi', 'Person'),
#  ('Belushi', 'Person'),
#  ('Robin', 'Person'),
#  ('Pam Dawber', 'Person'),
#  ('Robin Williams', 'Person'),
#  ('Mork', 'Person'),
#  ('Mindy', 'Person'),
#  ('Nanoo', 'Person'),
#  ('John Woos', 'Person'),
#  ('Hong Kong', 'City'),
#  ('Tampopo', 'City'),
#  ('Steven Okazaki', 'Person'),
#  ('Quaalude', 'Person'),
#  ('Brenda Aoki', 'Person'),
#  ('Joseph Meeker', 'Person'),
#  ('Michael Silvano', 'Person'),
#  ('Alex', 'Person'),
#  ('Kelly Perine', 'Person'),
#  ('Silvanos', 'Person'),
#  ('Silvano', 'Person'),
#  ('David Keith', 'Person'),
#  ('Elvis', 'City'),
#  ('Martin Kove', 'Person'),
#  ('Keith', 'Person'),
#  ('Silvano', 'Person'),
#  ('John Eyres', 'Person'),
#  ('Keith', 'Person'),
#  ('Kove', 'Person'),
#  ('Paul Koslo', 'Person'),
#  ('Kelly Perine', 'Person'),
#  ('Purple Butterfly', 'Person'),
#  ('Purple Butterfly', 'Person'),
#  ('Shanghai', 'City'),
#  ('Ding Hui Zhang Ziyi', 'Person'),
#  ('Hidehiko Itami Toru Nakamura', 'Person'),
#  ('Paris', 'City'),
#  ('Georgia', 'City'),
#  ('Michael Bay', 'Person'),
#  ('Zhang Ziyi', 'Person'),
#  ('Michael Biehn', 'Person'),
#  ('Linda Hamilton', 'Person'),
#  ('Suzhou', 'City'),
#  ('George Orwells', 'Person'),
#  ('Burton', 'Person'),
#  ('Winston', 'Person'),
#  ('Hollywood', 'City'),
#  ('Betty Boop', 'Person'),
#  ('Henry', 'Person'),
#  ('Betty Boops', 'Person'),
#  ('Betty', 'Person'),
#  ('Henry', 'Person'),
#  ('Catwoman', 'Person'),
#  ('Afghanistan', 'City'),
#  ('Osama bin Ladenbr', 'Person'),
#  ('Tarzan', 'City'),
#  ('Tarzan', 'City'),
#  ('Christopher Lambert', 'Person'),
#  ('Andie MacDowells', 'Person'),
#  ('Ian Holme', 'Person'),
#  ('Lambert', 'Person'),
#  ('Tarzan', 'City'),
#  ('Lambert', 'Person'),
#  ('Lambert', 'Person'),
#  ('Ben Charles Bateman', 'Person'),
#  ('Nicky Ahna Capri', 'Person'),
#  ('Geri Reischl', 'Person'),
#  ('Hillsboro', 'Person'),
#  ('Capri', 'Person'),
#  ('Strother Martin', 'Person'),
#  ('gore', 'Person'),
#  ('Martin', 'Person'),
#  ('Francis Ford Coppola', 'Person'),
#  ('Shirley Knight', 'Person'),
#  ('James Caan', 'Person'),
#  ('Robert Duvall', 'Person'),
#  ('Simon Says', 'Person'),
#  ('Kevin Bacon', 'Person'),
#  ('Gary Thompson', 'Person'),
#  ('Andrew Marlowe', 'Person'),
#  ('Monster Movie', 'Person'),
#  ('Lets', 'Person'),
#  ('Kevin Bacon', 'Person'),
#  ('Errol Flynns', 'Person'),
#  ('Humphrey Bogart', 'Person'),
#  ('Casablanca', 'City'),
#  ('Forrest Tucker', 'Person'),
#  ('Tucker', 'Person'),
#  ('Flynn', 'Person'),
#  ('Eleanor Parker', 'Person'),
#  ('Patti Brady', 'Person'),
#  ('Richard Gere Emran', 'Person'),
#  ('Olivier', 'City'),
#  ('Malikka', 'Person'),
#  ('Bollywood', 'City'),
#  ('Oscar', 'Person'),
#  ('Robert Altmans', 'Person'),
#  ('Edmund Naughtons', 'Person'),
#  ('McCabe', 'Person'),
#  ('Warren Beatty', 'Person'),
#  ('Beatty', 'City'),
#  ('Altmanquirky', 'Person'),
#  ('Conan', 'Person'),
#  ('Carson', 'Person'),
#  ('Andy Griffiths', 'Person'),
#  ('Keira Knightley', 'Person'),
#  ('Elizabeth Bennet', 'Person'),
#  ('Joe Wright', 'Person'),
#  ('Jane Austens', 'Person'),
#  ('Ucertificate Wuthering Heights', 'City'),
#  ('Elizabeth', 'Person'),
#  ('Darcy', 'Person'),
#  ('Jane Austen', 'Person'),
#  ('Matrix', 'Person'),
#  ('Jane', 'Person'),
#  ('Jane Austen', 'Person'),
#  ('Prejudice', 'Person'),
#  ('Jane Austens', 'Person'),
#  ('Elizabeth Bennett', 'Person'),
#  ('Keira Knightley', 'Person'),
#  ('Austens Elizabeth', 'Person'),
#  ('Austens', 'City'),
#  ('Knightleys Elizabeth', 'Person'),
#  ('Matthew Macfaydenbr br Donald Sutherland', 'Person'),
#  ('Mr Bennet', 'Person'),
#  ('Mr Bennet', 'Person'),
#  ('Lizzie', 'Person'),
#  ('Mr Bingley', 'Person'),
#  ('Jane', 'Person'),
#  ('Jane Austen', 'Person'),
#  ('Norman Macleans', 'Person'),
#  ('Life', 'Person'),
#  ('Robert Redford', 'Person'),
#  ('Craig Sheffer', 'Person'),
#  ('Brad Pitt', 'Person'),
#  ('Tom Skerritt', 'Person'),
#  ('Brenda Blethyns', 'Person'),
#  ('Rafael', 'Person'),
#  ('Asi Dayan', 'Person'),
#  ('Blind', 'Person'),
#  ('Taly Sharon', 'Person'),
#  ('Greeceeven', 'Person'),
#  ('Mourikis', 'City'),
#  ('MYSTERY MEN', 'Person'),
#  ('Romania', 'City'),
#  ('Michael Pare', 'Person'),
#  ('Gargoyles', 'Person'),
#  ('Van Helsing', 'Person'),
#  ('Mo Ogrodnik', 'Person'),
#  ('Wolfgang Somethings', 'Person'),
#  ('Mo', 'Person'),
#  ('Didos', 'Person'),
#  ('Lolita', 'City'),
#  ('Mo Ogrodniks', 'Person'),
#  ('Punch Jr', 'Person'),
#  ('Beatles', 'Person'),
#  ('John Lennon', 'Person'),
#  ('Paul McCartney', 'Person'),
#  ('Beatles', 'Person'),
#  ('Jared Harris Stars', 'Person'),
#  ('John', 'Person'),
#  ('Aiden Quinn', 'Person'),
#  ('Paul', 'Person'),
#  ('Harris', 'Person'),
#  ('McCartney', 'Person'),
#  ('Harris', 'Person'),
#  ('McCartney', 'Person'),
#  ('Beatles', 'Person'),
#  ('Beatles', 'Person'),
#  ('John Lennon', 'Person'),
#  ('Paul McCartney', 'Person'),
#  ('London', 'City'),
#  ('Paris', 'City'),
#  ('KG', 'Person'),
#  ('Jaybles portray', 'Person'),
#  ('LeTourneau', 'Person'),
#  ('Vili', 'Person'),
#  ('LeTourneau', 'Person'),
#  ('LeTourneau', 'Person'),
#  ('London', 'City'),
#  ('Karva', 'Person'),
#  ('Runner', 'Person'),
#  ('Karva', 'Person'),
#  ('Tony Grisoni', 'Person'),
#  ('Terry Gilliam', 'Person'),
#  ('Jack', 'Person'),
#  ('Russ', 'Person'),
#  ('Bruce Willis', 'Person'),
#  ('Phat Beach', 'Person'),
#  ('hoop', 'Person'),
#  ('Relativity Quantum String', 'Person'),
#  ('Mtheorybr', 'Person'),
#  ('Bravo Brian Greene', 'Person'),
#  ('Texas', 'City'),
#  ('Universe', 'City'),
#  ('Batman Mask of the', 'Person'),
#  ('Batwoman', 'Person'),
#  ('Batman', 'Person'),
#  ('Gotham', 'Person'),
#  ('Rupert Thorne', 'Person'),
#  ('Oswald Cobblepot', 'Person'),
#  ('Batman', 'Person'),
#  ('Batman', 'Person'),
#  ('Kevin Conroy', 'Person'),
#  ('Bruce Wayne', 'Person'),
#  ('Batman', 'Person'),
#  ('Bob Hastings', 'Person'),
#  ('Barbara GordonBatgirl', 'Person'),
#  ('Bruce', 'Person'),
#  ('Rupert Thorne', 'Person'),
#  ('Marquis', 'Person'),
#  ('Hollywood', 'City'),
#  ('manMickey Rooney', 'Person'),
#  ('Steve Johnsons', 'Person'),
#  ('Kevin Tenney', 'Person'),
#  ('Cama de Gato', 'Person'),
#  ('Alexandre Stockler', 'Person'),
#  ('Cama de Gato', 'Person'),
#  ('Larry Clark', 'Person'),
#  ('Stockler', 'Person'),
#  ('Stockler', 'Person'),
#  ('Brazil', 'City'),
#  ('Sal Mineos Blat', 'Person'),
#  ('Stockler', 'Person'),
#  ('Cama de Gato', 'Person'),
#  ('Cama de Gato', 'Person'),
#  ('Charlie', 'Person'),
#  ('Burt Reynolds', 'Person'),
#  ('Dom DeLuise', 'Person'),
#  ('Judith Barsi', 'Person'),
#  ('God', 'Person'),
#  ('Don Bluth', 'Person'),
#  ('Dom DeLuise', 'Person'),
#  ('Steve Carell', 'Person'),
#  ('Wanda Sykes', 'Person'),
#  ('Bruce', 'Person'),
#  ('Evan', 'Person'),
#  ('Bulgakovs', 'City'),
#  ('US', 'City'),
#  ('Leo Fong', 'Person'),
#  ('Fong', 'Person'),
#  ('Richard Roundtreebr', 'Person'),
#  ('Ill', 'Person'),
#  ('Azumi 2 Death or Love', 'Person'),
#  ('Azumi 2', 'Person'),
#  ('Azumi', 'Person'),
#  ('Chiaki', 'Person'),
#  ...]

# %%
len(list_ner)
# Out:
# 26247

# %% [markdown]
# Keeping only unique elements in the list, without losing the order.
# Reason: Redundancy of names if mentioned more than once.
# Can pe pre-processed more, but quick drafts limits to this.

# %%
def f7(seq):
    seen = set()
    seen_add = seen.add
    return [x for x in seq if not (x in seen or seen_add(x))]
final=f7(list_ner)

# %%
len(final)
# Out:
# 14492

# %%
final
# Out:
# [('Oz', 'Person'),
#  ('Emerald City', 'City'),
#  ('Michael Sheen', 'Person'),
#  ('Williams', 'Person'),
#  ('Orton', 'Person'),
#  ('Halliwell', 'Person'),
#  ('Woody Allen', 'Person'),
#  ('Scarlet Johanson', 'Person'),
#  ('Devil Wears Prada', 'Person'),
#  ('Jake', 'Person'),
#  ('Rambo', 'Person'),
#  ('Jake', 'City'),
#  ('Petter Matteis Love', 'Person'),
#  ('Mr Mattei', 'Person'),
#  ('Arthur', 'Person'),
#  ('New York', 'City'),
#  ('Mr Matteis', 'Person'),
#  ('Steve Buscemi Rosario Dawson Carol Kane', 'Person'),
#  ('Michael Imperioli', 'Person'),
#  ('Adrian Grenier', 'Person'),
#  ('Paul Lukas', 'Person'),
#  ('Bette Davis', 'Person'),
#  ('weekYou', 'Person'),
#  ('Harvey Keitel', 'City'),
#  ('Phil the Alien', 'Person'),
#  ('Psycho', 'Person'),
#  ('Janet Leigh', 'Person'),
#  ('Ralf Moellerbr', 'Person'),
#  ('Jack Carver', 'Person'),
#  ('Til Schweiger', 'Person'),
#  ('Carver', 'City'),
#  ('Tils', 'City'),
#  ('Udo Kier', 'Person'),
#  ('mehehe', 'City'),
#  ('Shakespeare', 'Person'),
#  ('Rev Bowdler', 'Person'),
#  ('george clooney', 'Person'),
#  ('Greetings Bart', 'Person'),
#  ('Rosanna Arquette', 'Person'),
#  ('Liam Neeson', 'Person'),
#  ('Owen Wilson', 'Person'),
#  ('Luke', 'Person'),
#  ('Shirley Jackson', 'Person'),
#  ('Matrix br br Examplesbr', 'Person'),
#  ('Yoda Obee', 'Person'),
#  ('hellobr br', 'Person'),
#  ('Newbury', 'City'),
#  ('Grizzly Adams', 'Person'),
#  ('Dan Haggery', 'Person'),
#  ('knowThe', 'Person'),
#  ('Cliffhanger Die Hard', 'Person'),
#  ('Sly Stop', 'Person'),
#  ('Cliffhanger', 'Person'),
#  ('John Lithgows', 'Person'),
#  ('Rex Linn', 'Person'),
#  ('Michael Rooker', 'Person'),
#  ('Ralph Waites Frank', 'Person'),
#  ('Londons Burning', 'Person'),
#  ('Craig Fairbrass', 'Person'),
#  ('Rajnikanth', 'Person'),
#  ('Speed Racer', 'Person'),
#  ('Preschool', 'City'),
#  ('Godzilla', 'Person'),
#  ('JoelMike', 'Person'),
#  ('Karen Carpenters', 'Person'),
#  ('Cynthia Gibb', 'Person'),
#  ('Karen', 'Person'),
#  ('Karen Carpenter', 'Person'),
#  ('Louise Fletcher', 'Person'),
#  ('Agnes Carpenter', 'Person'),
#  ('USA', 'City'),
#  ('Tarsem Singh', 'Person'),
#  ('Tarsem', 'City'),
#  ('Jennifer Lopez', 'Person'),
#  ('The Cell', 'Person'),
#  ('Oscars', 'City'),
#  ('Hollywood', 'City'),
#  ('Latino', 'Person'),
#  ('Horrible', 'Person'),
#  ('Jude Law Nicole Kidman', 'Person'),
#  ('Rene Zellweger', 'Person'),
#  ('Edward Zwick', 'Person'),
#  ('Jude Law', 'Person'),
#  ('Ada Monroe', 'Person'),
#  ('Nicole Kidman', 'Person'),
#  ('Inman', 'Person'),
#  ('Ruby Thewes', 'Person'),
#  ('Brendan Gleeson', 'Person'),
#  ('Ray Winstone', 'Person'),
#  ('Natalie Portman', 'Person'),
#  ('Virginia', 'City'),
#  ('North Carolina', 'City'),
#  ('Anthony Minghella', 'Person'),
#  ('Edward Dmytryks Crossfire', 'Person'),
#  ('Bivouacked', 'City'),
#  ('Washington DC', 'City'),
#  ('Robert Ryan', 'Person'),
#  ('Sam Levene', 'Person'),
#  ('Robert Young', 'Person'),
#  ('Robert Mitchum', 'Person'),
#  ('George Cooper', 'Person'),
#  ('Ryan', 'Person'),
#  ('Steve Brodie', 'Person'),
#  ('John Paxton Dmytryk', 'Person'),
#  ('Bobs Ryan', 'Person'),
#  ('Angry White Male', 'Person'),
#  ('Mitchum', 'Person'),
#  ('Young', 'Person'),
#  ('Gloria Grahame', 'Person'),
#  ('Paul Kelly', 'Person'),
#  ('Crossfire', 'Person'),
#  ('Richard Brooks', 'Person'),
#  ('Brick Foxhole', 'Person'),
#  ('homophobia', 'City'),
#  ('Ardh Satya', 'Person'),
#  ('Govind Nihalani', 'Person'),
#  ('India', 'City'),
#  ('Anand Velankar', 'Person'),
#  ('Cop', 'Person'),
#  ('Constable Anand', 'City'),
#  ('Anands', 'Person'),
#  ('Anands', 'City'),
#  ('Spirit', 'Person'),
#  ('Anand', 'Person'),
#  ('Underworld', 'City'),
#  ('Rama Shettys', 'Person'),
#  ('Mumbai', 'City'),
#  ('Titta Di', 'Person'),
#  ('Girolamo', 'City'),
#  ('Switzerland', 'City'),
#  ('Di Girolamos', 'Person'),
#  ('Titta', 'City'),
#  ('Girolamos', 'City'),
#  ('Never', 'Person'),
#  ('Italy', 'City'),
#  ('Anna', 'Person'),
#  ('Tittas', 'City'),
#  ('London', 'City'),
#  ('Blockbuster', 'Person'),
#  ('Ranmaesque', 'Person'),
#  ('Ray Stevens', 'Person'),
#  ('Jesus Wear', 'Person'),
#  ('PG13', 'Person'),
#  ('Zack', 'Person'),
#  ('Reba', 'City'),
#  ('The Virgin Suicides', 'City'),
#  ('hopebr br', 'Person'),
#  ('UK', 'City'),
#  ('David Morses', 'Person'),
#  ('David Morse', 'Person'),
#  ('David Koepp', 'Person'),
#  ('US', 'City'),
#  ('Iraq', 'City'),
#  ('Nicholas Cage', 'Person'),
#  ('misogyny', 'Person'),
#  ('James Wood', 'Person'),
#  ('Cuba', 'City'),
#  ('China', 'City'),
#  ('Hong Kong', 'City'),
#  ('Jennifer Jones', 'Person'),
#  ('Oscar', 'Person'),
#  ('William Holden', 'Person'),
#  ('Gary Busey', 'Person'),
#  ('Gary', 'Person'),
#  ('Dutcher', 'Person'),
#  ('Mormon', 'Person'),
#  ('laughablebr br Dutchers', 'Person'),
#  ('Mormon', 'City'),
#  ('California', 'City'),
#  ('Michael Douglas', 'Person'),
#  ('Kasey', 'Person'),
#  ('Goldie Hawn', 'Person'),
#  ('a Goldie Hawn', 'Person'),
#  ('Drama', 'Person'),
#  ('John Voight', 'Person'),
#  ('Mary Steenburgen', 'Person'),
#  ('Hercules Abraham', 'Person'),
#  ('Moses', 'Person'),
#  ('Noah Lot Abrahams', 'City'),
#  ('Lot', 'Person'),
#  ('Noah', 'Person'),
#  ('Herman Mankiewicz', 'Person'),
#  ('Orson Welles', 'Person'),
#  ('Kael', 'Person'),
#  ('Charles Foster Kane', 'Person'),
#  ('Ralston', 'Person'),
#  ('Bernstein Jed', 'Person'),
#  ('Susan Alexander Kane', 'Person'),
#  ('Raymond', 'Person'),
#  ('Kane', 'Person'),
#  ('KANE', 'Person'),
#  ('Tom Garner Spencer', 'Person'),
#  ('Henry Ralph Morgan', 'Person'),
#  ('Sarah Padden', 'Person'),
#  ('Garner Henry', 'Person'),
#  ('Tom', 'Person'),
#  ('Henry', 'Person'),
#  ('Toms', 'Person'),
#  ('Colleen Moore', 'Person'),
#  ('Sally', 'Person'),
#  ('America', 'City'),
#  ('Eve Helen Vinson', 'Person'),
#  ('Henry Eve', 'Person'),
#  ('Tom Jr Philip', 'Person'),
#  ('Sturgis', 'Person'),
#  ('Fulcis', 'City'),
#  ('Gordon Liu', 'Person'),
#  ('Liu', 'Person'),
#  ('Shaolin', 'Person'),
#  ('Shaolin Temple', 'Person'),
#  ('Mr Miyagis', 'Person'),
#  ('Karate Kid', 'City'),
#  ('Yuen Wo Ping', 'Person'),
#  ('Jimmy Davis', 'Person'),
#  ('Jimmy', 'Person'),
#  ('Fred P Willis Spencer', 'Person'),
#  ('France', 'City'),
#  ('Rose Duffy Gladys George Rose', 'Person'),
#  ('Fred', 'Person'),
#  ('Rose', 'Person'),
#  ('Jimmy', 'City'),
#  ('New York City', 'City'),
#  ('New York Citys', 'City'),
#  ('Fred later', 'Person'),
#  ('Bela Lugosi', 'Person'),
#  ('Bela', 'Person'),
#  ('Belas', 'City'),
#  ('W Bush', 'Person'),
#  ('Robespierre', 'Person'),
#  ('Selfdefense', 'Person'),
#  ('Gordon Eriksen', 'Person'),
#  ('gore', 'Person'),
#  ('The Hills Have', 'City'),
#  ('Hattie McDaniel', 'Person'),
#  ('Hitchcocks', 'Person'),
#  ('Rebecca', 'Person'),
#  ('Daphne DuMariers', 'Person'),
#  ('Jack Skirball', 'Person'),
#  ('Dorothy Parker', 'Person'),
#  ('Barry Kane Robert Cummings', 'Person'),
#  ('Frank Frye Norman Lloydd', 'Person'),
#  ('Soda City Utah', 'City'),
#  ('Patricia Martin Priscilla Lane', 'Person'),
#  ('Hitchcock Patricia', 'Person'),
#  ('Barry falls', 'Person'),
#  ('Saboteur', 'Person'),
#  ('Albert Finney', 'Person'),
#  ('Tom Courtenay', 'Person'),
#  ('The Dresser', 'Person'),
#  ('Finney', 'Person'),
#  ('Norman Courtenay', 'Person'),
#  ('King Lear', 'Person'),
#  ('Norman', 'Person'),
#  ('Courtenay', 'Person'),
#  ('Employer', 'Person'),
#  ('Finney Courtenay', 'Person'),
#  ('Ronald Harwood', 'Person'),
#  ('Eileen Atkins', 'Person'),
#  ('Madge', 'Person'),
#  ('Peter Yates', 'Person'),
#  ('Steve Martin', 'Person'),
#  ('Kate', 'Person'),
#  ('Fingersmith', 'Person'),
#  ('lets beginbr', 'Person'),
#  ('JJL', 'Person'),
#  ('Stella Bette Midler', 'Person'),
#  ('Stephen Collins', 'Person'),
#  ('Jenny Trini Alvarado', 'Person'),
#  ('Stella Dallas', 'Person'),
#  ('Midler', 'Person'),
#  ('Alvarado', 'Person'),
#  ('Marsha Mason', 'Person'),
#  ('Flimsy', 'Person'),
#  ('Reallywho', 'Person'),
#  ('Stanwyck', 'Person'),
#  ('Fulcis', 'Person'),
#  ('Busty', 'City'),
#  ('Jim Wynorski', 'Person'),
#  ('Salman Kahn', 'Person'),
#  ('Salman', 'Person'),
#  ('Marques Houston', 'Person'),
#  ('Okayso Reid', 'Person'),
#  ('Martin', 'Person'),
#  ('m sorryKym Whitley', 'Person'),
#  ('Robin Harris Ketty', 'Person'),
#  ('Meagen Good', 'Person'),
#  ('Mari Morrow', 'Person'),
#  ('Hudlin', 'Person'),
#  ('Max Q', 'Person'),
#  ('Bill Campbell', 'Person'),
#  ('Robert Stack', 'Person'),
#  ('Ted Knight', 'Person'),
#  ('Jackie Mason', 'Person'),
#  ('Rodney Dangerfield Ty Webb', 'Person'),
#  ('Henry Wilcoxon', 'Person'),
#  ('Peter Blunt', 'Person'),
#  ('Randy Quaid', 'Person'),
#  ('Dan Acroyd', 'Person'),
#  ('Bill Murray', 'Person'),
#  ('necrophilia', 'City'),
#  ('GENESIS', 'Person'),
#  ('Cerda', 'Person'),
#  ('Mukhsin', 'Person'),
#  ('Yasmin', 'Person'),
#  ('Gubra', 'Person'),
#  ('Gubra', 'City'),
#  ('Rumah', 'Person'),
#  ('Mukhsins', 'Person'),
#  ('Harry Vardon', 'Person'),
#  ('Francis', 'Person'),
#  ('Francis', 'City'),
#  ('Ed Wood', 'Person'),
#  ('Ed', 'Person'),
#  ('Russ Meyer', 'Person'),
#  ('Ren Hoek', 'Person'),
#  ('Tobe Hoopers', 'Person'),
#  ('Blood Surf', 'Person'),
#  ('Jaws Temple', 'Person'),
#  ('James Bond', 'Person'),
#  ('Sh Kasugi', 'Person'),
#  ('Christopher Lee', 'Person'),
#  ('JohnRhys', 'Person'),
#  ('Errol Flynn', 'Person'),
#  ('James Coburn', 'Person'),
#  ('Charlton Heston', 'Person'),
#  ('Barbara Hershey Coburn', 'Person'),
#  ('Heston', 'Person'),
#  ('Coburn', 'Person'),
#  ('Hershey', 'City'),
#  ('Morgan', 'Person'),
#  ('Thalmus Rasulala John Quade', 'Person'),
#  ('Larry Wilcox', 'Person'),
#  ('Jorge Rivero Heston', 'Person'),
#  ('Chris Mitchum', 'Person'),
#  ('Andrew McLaglen', 'Person'),
#  ('Porno Holocaust', 'Person'),
#  ('Entrails', 'Person'),
#  ('Kazuo Gaira Komizu', 'Person'),
#  ('Murderer', 'Person'),
#  ('Olympic', 'City'),
#  ('Gaira', 'Person'),
#  ('Sharif', 'Person'),
#  ('God', 'Person'),
#  ('Kurtz', 'Person'),
#  ('Medved', 'City'),
#  ('Doug Block', 'Person'),
#  ('Mina', 'Person'),
#  ('Mike', 'Person'),
#  ('Minas', 'Person'),
#  ('Doug', 'Person'),
#  ('Stephen Hawkings', 'Person'),
#  ('Einstein', 'Person'),
#  ('Lou Gehrigs', 'Person'),
#  ('Nora Roberts', 'Person'),
#  ('Australia', 'City'),
#  ('Primeval', 'Person'),
#  ('Walter Sparrow', 'Person'),
#  ('Joel Schumacher', 'Person'),
#  ('Carrey', 'Person'),
#  ('Jim Carrey', 'Person'),
#  ('Virginia Madsen', 'Person'),
#  ('Logan Lerman', 'Person'),
#  ('Danny Huston', 'Person'),
#  ('Drew Fuller', 'Person'),
#  ('Steele', 'Person'),
#  ('Ophelia', 'Person'),
#  ('Gilbert', 'Person'),
#  ('Brad Johnson', 'Person'),
#  ('Matt', 'Person'),
#  ('Pip', 'Person'),
#  ('Janine Turner', 'Person'),
#  ('Nicholas Walker', 'Person'),
#  ('Paul', 'Person'),
#  ('Reverand', 'Person'),
#  ('Martha Ally Sheedy', 'Person'),
#  ('Veronica Dara Tomanovich', 'Person'),
#  ('Sally Kirkland', 'Person'),
#  ('John Savage', 'Person'),
#  ('Daredevil Elektra Ghost Rider', 'Person'),
#  ('Gore Verbinsky', 'Person'),
#  ('Grudge', 'Person'),
#  ('Amber Tamblyn', 'Person'),
#  ('Aubrey Tamblyn', 'Person'),
#  ('Karen Sarah Michelle Gellar', 'Person'),
#  ('Allison Arielle Kebbel', 'Person'),
#  ('Glad', 'Person'),
#  ('Down Periscope', 'Person'),
#  ('Mobile', 'City'),
#  ('Alabama', 'City'),
#  ('Cub Scouts', 'Person'),
#  ('Kelsey Grammar Lauren Holly', 'Person'),
#  ('Rob Schneider', 'Person'),
#  ('Blade', 'City'),
#  ('Deanna Durbin Nan Grey', 'Person'),
#  ('Barbara Read', 'Person'),
#  ('Universal', 'Person'),
#  ('Deanna Durbin', 'Person'),
#  ('Ray Milland', 'Person'),
#  ('Mischa Auer', 'Person'),
#  ('Charles Winninger', 'Person'),
#  ('John King Binnie Barnes', 'Person'),
#  ('Alice Brady', 'Person'),
#  ('Winninger', 'Person'),
#  ('Brady', 'Person'),
#  ('Auer', 'Person'),
#  ('Milland', 'Person'),
#  ('Auer Milland Barnes', 'Person'),
#  ('Durbin', 'Person'),
#  ('Il Bacio', 'City'),
#  ('Deanna', 'Person'),
#  ('England', 'City'),
#  ('Alfred Molina', 'Person'),
#  ('Lawrence Jim', 'Person'),
#  ('Miranda Richardson', 'Person'),
#  ('Michael Kitchens', 'Person'),
#  ('Mike Newell', 'Person'),
#  ('Cedric Hardwicke', 'Person'),
#  ('LASTING', 'City'),
#  ('Daniel DayLewis', 'Person'),
#  ('Cristy Brown', 'Person'),
#  ('Eileen Peter', 'Person'),
#  ('Ill kick', 'Person'),
#  ('Cristys', 'City'),
#  ('sho yo', 'Person'),
#  ('Zeus', 'Person'),
#  ('Hera', 'Person'),
#  ('Ed Woods', 'Person'),
#  ('George W Bush', 'Person'),
#  ('Stay', 'Person'),
#  ('Mario', 'Person'),
#  ('Bowser', 'Person'),
#  ('Bowser Jr', 'Person'),
#  ('Princess Peach', 'Person'),
#  ('Mario falls', 'Person'),
#  ('Luma', 'Person'),
#  ('Rosalina Rosalina', 'Person'),
#  ('Lumas', 'City'),
#  ('Peach', 'Person'),
#  ('Stars Mario', 'Person'),
#  ('Spatula Madness', 'Person'),
#  ('Edward the Spatula', 'Person'),
#  ('Mr Van Bebble', 'Person'),
#  ('Chicago', 'City'),
#  ('Oliver Stone', 'Person'),
#  ('Terry Gilliam', 'Person'),
#  ('Charlie', 'Person'),
#  ('Van Bebbles', 'Person'),
#  ('Helter Skelter', 'Person'),
#  ('Mtv', 'Person'),
#  ('Rocky Horroresque', 'Person'),
#  ('Lie', 'Person'),
#  ('Dungeons', 'Person'),
#  ('Sadie', 'Person'),
#  ('Linda', 'Person'),
#  ('madeforTV', 'Person'),
#  ('Richard Crenna', 'Person'),
#  ('Yvette Mimieux', 'Person'),
#  ('Jackson County', 'City'),
#  ('Kim Richards', 'Person'),
#  ('Ike Eisenmann', 'Person'),
#  ('Martine Beswicke', 'Person'),
#  ('RG Armstrong', 'Person'),
#  ('Victor Jory', 'Person'),
#  ('Savannah', 'City'),
#  ('Georgia', 'City'),
#  ('Dell Henderson', 'Person'),
#  ('William Haines', 'Person'),
#  ('Andre Telefair', 'Person'),
#  ('Charles Chaplin', 'Person'),
#  ('John Gilbert', 'Person'),
#  ('Kronos', 'City'),
#  ('Klingon', 'City'),
#  ('Kirk', 'Person'),
#  ('William Shatner', 'Person'),
#  ('McCoy', 'Person'),
#  ('Shatner', 'Person'),
#  ('Spencer Tracy', 'Person'),
#  ('Helen Vinson', 'Person'),
#  ('Dalton', 'Person'),
#  ('Rochester', 'Person'),
#  ('Jane Eyre', 'Person'),
#  ('Zelah Clark', 'Person'),
#  ('Jonathan Tanner', 'Person'),
#  ('Cox', 'Person'),
#  ('Borges', 'Person'),
#  ('Lonnrot', 'Person'),
#  ('Aussie', 'Person'),
#  ('Aidan Quinn', 'Person'),
#  ('Quinn', 'City'),
#  ('Donald Sutherland', 'Person'),
#  ('Quinn Ben Kingsley', 'Person'),
#  ('paris', 'City'),
#  ('Louis XVI', 'Person'),
#  ('Danton Gerard Depardieu', 'Person'),
#  ('Wojciech Pszoniak', 'Person'),
#  ('Paris', 'City'),
#  ('Andrzej Wajda', 'Person'),
#  ('Poland', 'City'),
#  ('Lech Walesa', 'Person'),
#  ('Jaruselski', 'Person'),
#  ('Danton', 'Person'),
#  ('Robespierre DantonWalesa', 'Person'),
#  ('Stanislawa Przybyszewska', 'Person'),
#  ('Corey Haims', 'Person'),
#  ('Nicole Eggert', 'Person'),
#  ('Pedro Almodvar', 'Person'),
#  ('Margaret Atwoods', 'Person'),
#  ('Zenias', 'Person'),
#  ('Roz Charis', 'Person'),
#  ('Toni', 'Person'),
#  ('Margaret Atwood', 'Person'),
#  ('Ingrid Bergman', 'Person'),
#  ('Walter Matthaus', 'Person'),
#  ('Matthau', 'Person'),
#  ('Bergman', 'Person'),
#  ('Goldie', 'Person'),
#  ('Hawn', 'Person'),
#  ('Learning', 'City'),
#  ('Winston Rekert', 'Person'),
#  ('Paul Sharpes', 'Person'),
#  ('Andrew Bednarski', 'Person'),
#  ('Matthew Sharpe', 'Person'),
#  ('John Novak', 'Person'),
#  ('Stewart Kaufman', 'Person'),
#  ('Rekert Mr', 'Person'),
#  ('Karen Black', 'Person'),
#  ('Janus', 'Person'),
#  ('Rekert', 'Person'),
#  ('Chuck', 'Person'),
#  ('RAMBO', 'Person'),
#  ('Edgar Allen', 'Person'),
#  ('Boris Karloff', 'Person'),
#  ('Dan Basinger 810', 'Person'),
#  ('Jack Frost', 'Person'),
#  ('Waaaaaaaaaaay', 'City'),
#  ('Michael Keaton', 'Person'),
#  ('revamp', 'Person'),
#  ('Halperin', 'Person'),
#  ('White Zombie', 'Person'),
#  ('Halperins', 'Person'),
#  ('Zombie', 'Person'),
#  ('Victor Halperin', 'Person'),
#  ('Ugly Betty', 'Person'),
#  ('Tim Daly', 'Person'),
#  ('Chris Lowell', 'Person'),
#  ('Hospitalor', 'Person'),
#  ('Ebert', 'Person'),
#  ('Yea', 'Person'),
#  ('Steve', 'Person'),
#  ('Jack Barclays', 'Person'),
#  ('Tony Leung', 'Person'),
#  ('Maggie Cheung', 'Person'),
#  ('Rudy', 'Person'),
#  ('Chris Makepeace', 'Person'),
#  ('Murray', 'Person'),
#  ('Corey Feldman', 'Person'),
#  ('Kool Moe Dee Carol Alt', 'Person'),
#  ('washedup hasbeen', 'Person'),
#  ('neverwass', 'Person'),
#  ('Gary Coleman', 'Person'),
#  ('Carol Alt', 'Person'),
#  ('Carol', 'Person'),
#  ('Anna Nicole Smith', 'Person'),
#  ('Ms Englishs', 'Person'),
#  ('Meg Ryan', 'Person'),
#  ('Annette Bening', 'Person'),
#  ('New Yorker', 'City'),
#  ('Lets', 'Person'),
#  ('Lee Radziwill', 'Person'),
#  ('Little Edie', 'Person'),
#  ('Yeoman Barrows', 'Person'),
#  ('Gene Roddenberry', 'Person'),
#  ('Irwin Allen', 'Person'),
#  ('curiosity', 'City'),
#  ('Mork', 'Person'),
#  ('Mindy', 'Person'),
#  ('Robin Williams', 'Person'),
#  ('Robin', 'Person'),
#  ('Robins', 'Person'),
#  ('Chris Diamantopoulos', 'Person'),
#  ('Mr Williams', 'Person'),
#  ('Andy Kaufman', 'Person'),
#  ('Garry Marshall', 'Person'),
#  ('John Belushi', 'Person'),
#  ('Belushi', 'Person'),
#  ('Pam Dawber', 'Person'),
#  ('Nanoo', 'Person'),
#  ('John Woos', 'Person'),
#  ('Tampopo', 'City'),
#  ('Steven Okazaki', 'Person'),
#  ('Quaalude', 'Person'),
#  ('Brenda Aoki', 'Person'),
#  ('Joseph Meeker', 'Person'),
#  ('Michael Silvano', 'Person'),
#  ('Alex', 'Person'),
#  ('Kelly Perine', 'Person'),
#  ('Silvanos', 'Person'),
#  ('Silvano', 'Person'),
#  ('David Keith', 'Person'),
#  ('Elvis', 'City'),
#  ('Martin Kove', 'Person'),
#  ('Keith', 'Person'),
#  ('John Eyres', 'Person'),
#  ('Kove', 'Person'),
#  ('Paul Koslo', 'Person'),
#  ('Purple Butterfly', 'Person'),
#  ('Shanghai', 'City'),
#  ('Ding Hui Zhang Ziyi', 'Person'),
#  ('Hidehiko Itami Toru Nakamura', 'Person'),
#  ('Michael Bay', 'Person'),
#  ('Zhang Ziyi', 'Person'),
#  ('Michael Biehn', 'Person'),
#  ('Linda Hamilton', 'Person'),
#  ('Suzhou', 'City'),
#  ('George Orwells', 'Person'),
#  ('Burton', 'Person'),
#  ('Winston', 'Person'),
#  ('Betty Boop', 'Person'),
#  ('Betty Boops', 'Person'),
#  ('Betty', 'Person'),
#  ('Catwoman', 'Person'),
#  ('Afghanistan', 'City'),
#  ('Osama bin Ladenbr', 'Person'),
#  ('Tarzan', 'City'),
#  ('Christopher Lambert', 'Person'),
#  ('Andie MacDowells', 'Person'),
#  ('Ian Holme', 'Person'),
#  ('Lambert', 'Person'),
#  ('Ben Charles Bateman', 'Person'),
#  ('Nicky Ahna Capri', 'Person'),
#  ('Geri Reischl', 'Person'),
#  ('Hillsboro', 'Person'),
#  ('Capri', 'Person'),
#  ('Strother Martin', 'Person'),
#  ('Francis Ford Coppola', 'Person'),
#  ('Shirley Knight', 'Person'),
#  ('James Caan', 'Person'),
#  ('Robert Duvall', 'Person'),
#  ('Simon Says', 'Person'),
#  ('Kevin Bacon', 'Person'),
#  ('Gary Thompson', 'Person'),
#  ('Andrew Marlowe', 'Person'),
#  ('Monster Movie', 'Person'),
#  ('Errol Flynns', 'Person'),
#  ('Humphrey Bogart', 'Person'),
#  ('Casablanca', 'City'),
#  ('Forrest Tucker', 'Person'),
#  ('Tucker', 'Person'),
#  ('Flynn', 'Person'),
#  ('Eleanor Parker', 'Person'),
#  ('Patti Brady', 'Person'),
#  ('Richard Gere Emran', 'Person'),
#  ('Olivier', 'City'),
#  ('Malikka', 'Person'),
#  ('Bollywood', 'City'),
#  ('Robert Altmans', 'Person'),
#  ('Edmund Naughtons', 'Person'),
#  ('McCabe', 'Person'),
#  ('Warren Beatty', 'Person'),
#  ('Beatty', 'City'),
#  ('Altmanquirky', 'Person'),
#  ('Conan', 'Person'),
#  ('Carson', 'Person'),
#  ('Andy Griffiths', 'Person'),
#  ('Keira Knightley', 'Person'),
#  ('Elizabeth Bennet', 'Person'),
#  ('Joe Wright', 'Person'),
#  ('Jane Austens', 'Person'),
#  ('Ucertificate Wuthering Heights', 'City'),
#  ('Elizabeth', 'Person'),
#  ('Darcy', 'Person'),
#  ('Jane Austen', 'Person'),
#  ('Matrix', 'Person'),
#  ('Jane', 'Person'),
#  ('Prejudice', 'Person'),
#  ('Elizabeth Bennett', 'Person'),
#  ('Austens Elizabeth', 'Person'),
#  ('Austens', 'City'),
#  ('Knightleys Elizabeth', 'Person'),
#  ('Matthew Macfaydenbr br Donald Sutherland', 'Person'),
#  ('Mr Bennet', 'Person'),
#  ('Lizzie', 'Person'),
#  ('Mr Bingley', 'Person'),
#  ('Norman Macleans', 'Person'),
#  ('Life', 'Person'),
#  ('Robert Redford', 'Person'),
#  ('Craig Sheffer', 'Person'),
#  ('Brad Pitt', 'Person'),
#  ('Tom Skerritt', 'Person'),
#  ('Brenda Blethyns', 'Person'),
#  ('Rafael', 'Person'),
#  ('Asi Dayan', 'Person'),
#  ('Blind', 'Person'),
#  ('Taly Sharon', 'Person'),
#  ('Greeceeven', 'Person'),
#  ('Mourikis', 'City'),
#  ('MYSTERY MEN', 'Person'),
#  ('Romania', 'City'),
#  ('Michael Pare', 'Person'),
#  ('Gargoyles', 'Person'),
#  ('Van Helsing', 'Person'),
#  ('Mo Ogrodnik', 'Person'),
#  ('Wolfgang Somethings', 'Person'),
#  ('Mo', 'Person'),
#  ('Didos', 'Person'),
#  ('Lolita', 'City'),
#  ('Mo Ogrodniks', 'Person'),
#  ('Punch Jr', 'Person'),
#  ('Beatles', 'Person'),
#  ('John Lennon', 'Person'),
#  ('Paul McCartney', 'Person'),
#  ('Jared Harris Stars', 'Person'),
#  ('John', 'Person'),
#  ('Aiden Quinn', 'Person'),
#  ('Harris', 'Person'),
#  ('McCartney', 'Person'),
#  ('KG', 'Person'),
#  ('Jaybles portray', 'Person'),
#  ('LeTourneau', 'Person'),
#  ('Vili', 'Person'),
#  ('Karva', 'Person'),
#  ('Runner', 'Person'),
#  ('Tony Grisoni', 'Person'),
#  ('Jack', 'Person'),
#  ('Russ', 'Person'),
#  ('Bruce Willis', 'Person'),
#  ('Phat Beach', 'Person'),
#  ('hoop', 'Person'),
#  ('Relativity Quantum String', 'Person'),
#  ('Mtheorybr', 'Person'),
#  ('Bravo Brian Greene', 'Person'),
#  ('Texas', 'City'),
#  ('Universe', 'City'),
#  ('Batman Mask of the', 'Person'),
#  ('Batwoman', 'Person'),
#  ('Batman', 'Person'),
#  ('Gotham', 'Person'),
#  ('Rupert Thorne', 'Person'),
#  ('Oswald Cobblepot', 'Person'),
#  ('Kevin Conroy', 'Person'),
#  ('Bruce Wayne', 'Person'),
#  ('Bob Hastings', 'Person'),
#  ('Barbara GordonBatgirl', 'Person'),
#  ('Bruce', 'Person'),
#  ('Marquis', 'Person'),
#  ('manMickey Rooney', 'Person'),
#  ('Steve Johnsons', 'Person'),
#  ('Kevin Tenney', 'Person'),
#  ('Cama de Gato', 'Person'),
#  ('Alexandre Stockler', 'Person'),
#  ('Larry Clark', 'Person'),
#  ('Stockler', 'Person'),
#  ('Brazil', 'City'),
#  ('Sal Mineos Blat', 'Person'),
#  ('Burt Reynolds', 'Person'),
#  ('Dom DeLuise', 'Person'),
#  ('Judith Barsi', 'Person'),
#  ('Don Bluth', 'Person'),
#  ('Steve Carell', 'Person'),
#  ('Wanda Sykes', 'Person'),
#  ('Evan', 'Person'),
#  ('Bulgakovs', 'City'),
#  ('Leo Fong', 'Person'),
#  ('Fong', 'Person'),
#  ('Richard Roundtreebr', 'Person'),
#  ('Ill', 'Person'),
#  ('Azumi 2 Death or Love', 'Person'),
#  ('Azumi 2', 'Person'),
#  ('Azumi', 'Person'),
#  ('Chiaki', 'Person'),
#  ('Bijomaru', 'City'),
#  ('Heath Ledger', 'Person'),
#  ('Naomi Watts', 'Person'),
#  ('Rachel Griffiths', 'Person'),
#  ('Geoffrey Rush', 'Person'),
#  ('Monty Python', 'Person'),
#  ('Ill bite yer', 'Person'),
#  ('Tyson', 'Person'),
#  ('Nacho Libre', 'Person'),
#  ('Jacks', 'Person'),
#  ('NOTHING', 'Person'),
#  ('Anne Rice', 'Person'),
#  ('Brad Pitts', 'Person'),
#  ('Korn', 'Person'),
#  ('Buttheadbr', 'City'),
#  ('John Carpenter', 'Person'),
#  ('Aaliyah', 'City'),
#  ('The Anne Rice', 'Person'),
#  ('Leonard Maltin', 'Person'),
#  ('BOMB', 'Person'),
#  ('Douglas Fairbanks 77', 'Person'),
#  ('George Hilton', 'Person'),
#  ('Gilbert Roland', 'Person'),
#  ('Mr Maltin', 'Person'),
#  ('Kudos', 'Person'),
#  ('the United States', 'City'),
#  ('br br', 'Person'),
#  ('Patrick Stewarts', 'Person'),
#  ('Claudius', 'Person'),
#  ('Gibson', 'Person'),
#  ('Jacoby', 'Person'),
#  ('Wittenburg', 'City'),
#  ('Hamlet', 'Person'),
#  ('Polonius', 'Person'),
#  ('Gertrude Claudius', 'Person'),
#  ('The Golden Door', 'City'),
#  ('Sicily', 'City'),
#  ('Salvatore', 'City'),
#  ('Salvatores', 'Person'),
#  ('Jack Elam', 'Person'),
#  ('Jean Willes', 'Person'),
#  ('John Hoyt', 'Person'),
#  ('John Archer', 'Person'),
#  ('Barney Phillips', 'Person'),
#  ('Bill Kendis', 'Person'),
#  ('USSR', 'City'),
#  ('Fox Kids', 'Person'),
#  ('kinda cool', 'Person'),
#  ('Reggie Bbr', 'Person'),
#  ('II', 'Person'),
#  ('IVbr', 'City'),
#  ('Annakin', 'Person'),
#  ('Amidala', 'City'),
#  ('Jedi', 'Person'),
#  ('Obiwan Kenobi', 'Person'),
#  ('Scotty Grant Cramer', 'Person'),
#  ('Killer Klowns', 'Person'),
#  ('Arthur Kennedy', 'Person'),
#  ('Libby Bacon', 'Person'),
#  ('Callie Hattie McDaniel', 'Person'),
#  ('McDaniel', 'Person'),
#  ('Moreland', 'Person'),
#  ('Ronald Reagans', 'Person'),
#  ('Reagan', 'Person'),
#  ('Richard Mulligans', 'Person'),
#  ('Custers', 'Person'),
#  ('Steven Seagal', 'Person'),
#  ('Jay Lenos', 'Person'),
#  ('Conan OBrien', 'Person'),
#  ('Jay Lenobr', 'Person'),
#  ('Ovitz', 'Person'),
#  ('Horatio Nelson', 'Person'),
#  ('the Ealing Rank', 'Person'),
#  ('Powell', 'Person'),
#  ('Eric Portman', 'Person'),
#  ('John Mills', 'Person'),
#  ('Antartica', 'City'),
#  ('Kurt Russell', 'Person'),
#  ('Rob Bottin', 'Person'),
#  ('John Carpenters', 'Person'),
#  ('justin', 'Person'),
#  ('Goldsworthy', 'Person'),
#  ('Goldsworthys', 'Person'),
#  ('William Hickey', 'Person'),
#  ('Don Anthony', 'Person'),
#  ('Godfather', 'Person'),
#  ('Eddie Deezen', 'Person'),
#  ('Laurel', 'City'),
#  ('Hardy', 'Person'),
#  ('Lemmon', 'Person'),
#  ('Brent Spiner', 'Person'),
#  ('Pretty Woman', 'Person'),
#  ('Edward Lewis', 'Person'),
#  ('Richard Gere', 'Person'),
#  ('Girls', 'Person'),
#  ('Guys', 'Person'),
#  ('Eddy', 'Person'),
#  ('Gary Sinise Kathy', 'Person'),
#  ('Joey Lauren Adams', 'Person'),
#  ('Jennifer Tilly', 'Person'),
#  ('Jamie Lynn', 'Person'),
#  ('herbr br', 'Person'),
#  ('Oedipus Rex', 'Person'),
#  ('Jackie Chan', 'Person'),
#  ('Jackie Chans', 'Person'),
#  ('James McNallys', 'Person'),
#  ('Nossiter', 'Person'),
#  ('De Montille', 'Person'),
#  ('John Ben Chaplin', 'Person'),
#  ('Russia', 'City'),
#  ('Nadia', 'City'),
#  ('Johns', 'City'),
#  ('Societys', 'City'),
#  ('Sophia', 'Person'),
#  ('Boa vs Python', 'Person'),
#  ('Claymation', 'City'),
#  ('Lifetime', 'City'),
#  ('Sally Field', 'Person'),
#  ('Kurt', 'Person'),
#  ('Remember Rememberto', 'Person'),
#  ('Howard Kevin Kline', 'Person'),
#  ('Indiana', 'City'),
#  ('Emily Joan Cusack', 'Person'),
#  ('Cameron Matt Dillon', 'Person'),
#  ('Oscar Everyone', 'Person'),
#  ('Howard', 'Person'),
#  ('Emily', 'Person'),
#  ('Cameron', 'Person'),
#  ('Cusack', 'Person'),
#  ('Dillon Bob Newhart Debbie', 'Person'),
#  ('Tom Selleck', 'Person'),
#  ('Denmark', 'City'),
#  ('Zulu', 'Person'),
#  ('Teddy Roosevelt', 'Person'),
#  ('Brian Keith', 'Person'),
#  ('Teddy', 'Person'),
#  ('Sean Connerys', 'Person'),
#  ('Candace Bergens', 'Person'),
#  ('John Hustons', 'Person'),
#  ('John Hay', 'Person'),
#  ('Steve Kanalys', 'Person'),
#  ('Eddie Murphys', 'Person'),
#  ('Ray Chicago', 'Person'),
#  ('Rent Ray', 'Person'),
#  ('Mascot', 'Person'),
#  ('Starewiczs', 'Person'),
#  ('Overall Starewicz', 'Person'),
#  ('JohnSiegfried Schrenbergcertainly', 'Person'),
#  ('Ann PortlandUschi Glas', 'Person'),
#  ('Ann', 'Person'),
#  ('Higgins', 'Person'),
#  ('Krimi', 'Person'),
#  ('Alfred Vohrer', 'Person'),
#  ('Steven', 'Person'),
#  ('Claire Danes', 'Person'),
#  ('William Shatner Impulse 1974', 'Person'),
#  ('Ron Liebmann', 'Person'),
#  ('Shatner', 'City'),
#  ('Liebmann', 'Person'),
#  ('Boothe', 'Person'),
#  ('Jim Jones', 'Person'),
#  ('Jim Jonesthis', 'Person'),
#  ('Ernesto', 'Person'),
#  ('Harry', 'Person'),
#  ('Steve Buscemi', 'Person'),
#  ('Quentin Tarintino', 'Person'),
#  ('Anthony Quinn', 'Person'),
#  ('Reese Witherspoon', 'Person'),
#  ('Kiefer', 'Person'),
#  ('Wesker', 'Person'),
#  ('Uday Chopra', 'Person'),
#  ('Halla Re', 'City'),
#  ('Barbara Stanwyck', 'Person'),
#  ('Edward G Robinson', 'Person'),
#  ('Robinson', 'Person'),
#  ('Barbara', 'Person'),
#  ('Dianne Foster', 'Person'),
#  ('Keiths Mexican', 'Person'),
#  ('Glenn Ford', 'Person'),
#  ('Bill Elliott', 'Person'),
#  ('Jubal', 'City'),
#  ('Andy Copps', 'Person'),
#  ('Beavis', 'Person'),
#  ('Emran Hashmi', 'Person'),
#  ('Hrshitta Bhatt', 'Person'),
#  ('Anu Malik', 'Person'),
#  ('Sini Ne', 'Person'),
#  ('Bhatts', 'Person'),
#  ('BJ Cook', 'Person'),
#  ('Skylark David Fosters old', 'Person'),
#  ('Giambone', 'Person'),
#  ('Law', 'Person'),
#  ('Sharon Stone', 'Person'),
#  ('Catherine Trammell', 'Person'),
#  ('Morrissey', 'Person'),
#  ('Glass', 'Person'),
#  ('Trammel', 'Person'),
#  ('Thewlisbr br Stone', 'Person'),
#  ('Casino Morrisey', 'Person'),
#  ('a Edgar Rice Burroughs', 'Person'),
#  ('McClure', 'Person'),
#  ('Caroline Munro', 'Person'),
#  ('Godfrey James Cy Grant', 'Person'),
#  ('Michael Crane', 'Person'),
#  ('Joe', 'Person'),
#  ('Jean', 'Person'),
#  ('Bryan Brown', 'Person'),
#  ('Yay', 'Person'),
#  ('Rosemary', 'Person'),
#  ('Thyme', 'Person'),
#  ('Sean Youngs', 'Person'),
#  ('Meryl Streep', 'Person'),
#  ('Lindy Chamberlain', 'Person'),
#  ('Mrs Chamberlain', 'Person'),
#  ('George Kennedy', 'Person'),
#  ('Concordes', 'Person'),
#  ('Robert Wagner Sylvia Kristel Alain Delon', 'Person'),
#  ('Martha Raye', 'Person'),
#  ('Chuck Connors', 'Person'),
#  ('Robert Reed', 'Person'),
#  ('Tina Louise', 'Person'),
#  ('defaultbr br', 'Person'),
#  ('Blake', 'Person'),
#  ('Meh', 'Person'),
#  ('Ed Hunt', 'Person'),
#  ('Barry Pearson', 'Person'),
#  ('David Gale', 'Person'),
#  ('Christine Kossak', 'Person'),
#  ('THE COMIC STRIP', 'City'),
#  ('Charles Bronson', 'Person'),
#  ...]

# %% [markdown]
# ### Creating required DataFrame and then generating out json file into the directory via function

# %%
data=pd.DataFrame(final,columns=['Name','Entity'])
data
# Out:
#                           Name  Entity
# 0                           Oz  Person
# 1                 Emerald City    City
# 2                Michael Sheen  Person
# 3                     Williams  Person
# 4                        Orton  Person
# ...                        ...     ...
# 14487        Lawrence Oliviers  Person
# 14488                       Li  Person
# 14489                     Tsui  Person
# 14490               Chris Gore  Person
# 14491  Backyard Wrestling Dvds  Person
#
# [14492 rows x 2 columns]

# %%
data.Entity.value_counts()
# Out:
# Person    12900
# City       1592
# Name: Entity, dtype: int64

# %%
with open('result.json', 'w') as f:
    f.write(data.to_json(orient='records', lines=True))
